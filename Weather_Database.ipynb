# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tarakan
# Processing Record 2 of Set 1 | bourail
# Processing Record 3 of Set 1 | hambantota
# Processing Record 4 of Set 1 | poum
# Processing Record 5 of Set 1 | tamworth
# Processing Record 6 of Set 1 | dianopolis
# City not found. Skipping...
# Processing Record 7 of Set 1 | coquimbo
# Processing Record 8 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 1 | tautira
# Processing Record 10 of Set 1 | lengshuijiang
# Processing Record 11 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | port hardy
# Processing Record 19 of Set 1 | jutai
# Processing Record 20 of Set 1 | dunedin
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | balkanabat
# Processing Record 23 of Set 1 | kahului
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | liwale
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | kidal
# Processing Record 35 of Set 1 | zabid
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | padang
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | qaqortoq
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | iskateley
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | kununurra
# Processing Record 1 of Set 2 | port moresby
# Processing Record 2 of Set 2 | kavaratti
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | karwar
# Processing Record 5 of Set 2 | saint-pierre
# Processing Record 6 of Set 2 | cabo san lucas
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | rikitea
# Processing Record 10 of Set 2 | broome
# Processing Record 11 of Set 2 | palauig
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | kudahuvadhoo
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | los llanos de aridane
# Processing Record 16 of Set 2 | oliveira dos brejinhos
# Processing Record 17 of Set 2 | sibolga
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | berlevag
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | kruisfontein
# Processing Record 26 of Set 2 | gat
# Processing Record 27 of Set 2 | palmer
# Processing Record 28 of Set 2 | gornopravdinsk
# Processing Record 29 of Set 2 | alappuzha
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | daru
# Processing Record 32 of Set 2 | vanimo
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | mount isa
# Processing Record 35 of Set 2 | slave lake
# Processing Record 36 of Set 2 | nome
# Processing Record 37 of Set 2 | saldanha
# Processing Record 38 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 2 | aykhal
# Processing Record 40 of Set 2 | juneau
# Processing Record 41 of Set 2 | kenai
# Processing Record 42 of Set 2 | ewa beach
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | xichang
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | hare bay
# Processing Record 50 of Set 2 | kavieng
# Processing Record 1 of Set 3 | yulara
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | taltal
# Processing Record 4 of Set 3 | horta
# Processing Record 5 of Set 3 | hofn
# Processing Record 6 of Set 3 | ferentino
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | beaverlodge
# Processing Record 11 of Set 3 | salinas
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | caravelas
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | lockport
# Processing Record 16 of Set 3 | saint anthony
# Processing Record 17 of Set 3 | mombetsu
# Processing Record 18 of Set 3 | ishigaki
# Processing Record 19 of Set 3 | makakilo city
# Processing Record 20 of Set 3 | truth or consequences
# Processing Record 21 of Set 3 | nevsehir
# Processing Record 22 of Set 3 | saint-joseph
# Processing Record 23 of Set 3 | ust-kan
# Processing Record 24 of Set 3 | chipata
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | wukari
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | ulladulla
# Processing Record 30 of Set 3 | saint-francois
# Processing Record 31 of Set 3 | buala
# Processing Record 32 of Set 3 | pacific grove
# Processing Record 33 of Set 3 | mukhen
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | nyrob
# Processing Record 36 of Set 3 | shache
# Processing Record 37 of Set 3 | gizo
# Processing Record 38 of Set 3 | amberley
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | minab
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | butaritari
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | kombissiri
# Processing Record 45 of Set 3 | beidao
# Processing Record 46 of Set 3 | azar shahr
# City not found. Skipping...
# Processing Record 47 of Set 3 | karratha
# Processing Record 48 of Set 3 | santa cruz del sur
# Processing Record 49 of Set 3 | obo
# Processing Record 50 of Set 3 | qasigiannguit
# Processing Record 1 of Set 4 | codrington
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | karpathos
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | at-bashi
# Processing Record 7 of Set 4 | manokwari
# Processing Record 8 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 4 | sola
# Processing Record 10 of Set 4 | byron bay
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | chapais
# Processing Record 13 of Set 4 | loandjili
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | zhezkazgan
# Processing Record 16 of Set 4 | roald
# Processing Record 17 of Set 4 | constitucion
# Processing Record 18 of Set 4 | izhma
# Processing Record 19 of Set 4 | marechal candido rondon
# Processing Record 20 of Set 4 | alice springs
# Processing Record 21 of Set 4 | kungurtug
# Processing Record 22 of Set 4 | nantucket
# Processing Record 23 of Set 4 | muisne
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | bereda
# Processing Record 26 of Set 4 | sinnamary
# Processing Record 27 of Set 4 | salalah
# Processing Record 28 of Set 4 | vao
# Processing Record 29 of Set 4 | nacala
# Processing Record 30 of Set 4 | kamenka
# Processing Record 31 of Set 4 | umm lajj
# Processing Record 32 of Set 4 | mar del plata
# Processing Record 33 of Set 4 | carutapera
# Processing Record 34 of Set 4 | bonnyville
# Processing Record 35 of Set 4 | khatanga
# Processing Record 36 of Set 4 | springbok
# Processing Record 37 of Set 4 | gazion
# City not found. Skipping...
# Processing Record 38 of Set 4 | zhigansk
# Processing Record 39 of Set 4 | chlorakas
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 4 | manta
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | brae
# Processing Record 45 of Set 4 | tigil
# Processing Record 46 of Set 4 | oyama
# Processing Record 47 of Set 4 | sept-iles
# Processing Record 48 of Set 4 | jiazi
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | belmonte
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | viedma
# Processing Record 3 of Set 5 | muros
# Processing Record 4 of Set 5 | sawakin
# Processing Record 5 of Set 5 | halifax
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | qaanaaq
# Processing Record 8 of Set 5 | troitskoye
# Processing Record 9 of Set 5 | brigantine
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | kohlu
# Processing Record 12 of Set 5 | kleive
# Processing Record 13 of Set 5 | tecoanapa
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | flinders
# Processing Record 16 of Set 5 | kalabo
# Processing Record 17 of Set 5 | carnduff
# Processing Record 18 of Set 5 | hilo
# Processing Record 19 of Set 5 | tugalan
# City not found. Skipping...
# Processing Record 20 of Set 5 | mayo
# Processing Record 21 of Set 5 | chunskiy
# Processing Record 22 of Set 5 | banff
# Processing Record 23 of Set 5 | kaitangata
# Processing Record 24 of Set 5 | braslav
# City not found. Skipping...
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | seydisehir
# Processing Record 28 of Set 5 | adrar
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | rocha
# Processing Record 31 of Set 5 | axim
# Processing Record 32 of Set 5 | lubao
# Processing Record 33 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 34 of Set 5 | conroe
# Processing Record 35 of Set 5 | san policarpo
# Processing Record 36 of Set 5 | ostrovnoy
# Processing Record 37 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 5 | serenje
# Processing Record 39 of Set 5 | ust-ilimsk
# Processing Record 40 of Set 5 | maracaju
# Processing Record 41 of Set 5 | batticaloa
# Processing Record 42 of Set 5 | labytnangi
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | guangyuan
# Processing Record 45 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | buraydah
# Processing Record 48 of Set 5 | rapid valley
# Processing Record 49 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 5 | okha
# Processing Record 1 of Set 6 | sitka
# Processing Record 2 of Set 6 | hovd
# Processing Record 3 of Set 6 | pringsewu
# Processing Record 4 of Set 6 | tabas
# Processing Record 5 of Set 6 | burkburnett
# Processing Record 6 of Set 6 | russell
# Processing Record 7 of Set 6 | rio das ostras
# Processing Record 8 of Set 6 | panjab
# Processing Record 9 of Set 6 | itacare
# Processing Record 10 of Set 6 | walvis bay
# Processing Record 11 of Set 6 | xinyang
# Processing Record 12 of Set 6 | san joaquin
# Processing Record 13 of Set 6 | pathein
# Processing Record 14 of Set 6 | chilca
# Processing Record 15 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 16 of Set 6 | trairi
# Processing Record 17 of Set 6 | batagay
# Processing Record 18 of Set 6 | voznesenye
# Processing Record 19 of Set 6 | presidencia roque saenz pena
# Processing Record 20 of Set 6 | stornoway
# Processing Record 21 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 6 | zhongxing
# Processing Record 23 of Set 6 | olinda
# Processing Record 24 of Set 6 | paro
# Processing Record 25 of Set 6 | corinto
# Processing Record 26 of Set 6 | pevek
# Processing Record 27 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 28 of Set 6 | heilbron
# Processing Record 29 of Set 6 | kodiak
# Processing Record 30 of Set 6 | kochi
# Processing Record 31 of Set 6 | saskylakh
# Processing Record 32 of Set 6 | karaton
# Processing Record 33 of Set 6 | gualaceo
# Processing Record 34 of Set 6 | santiago del estero
# Processing Record 35 of Set 6 | nelidovo
# Processing Record 36 of Set 6 | zhangye
# Processing Record 37 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 6 | deputatskiy
# Processing Record 40 of Set 6 | aksu
# Processing Record 41 of Set 6 | tuatapere
# Processing Record 42 of Set 6 | kulhudhuffushi
# Processing Record 43 of Set 6 | urupes
# Processing Record 44 of Set 6 | pangody
# Processing Record 45 of Set 6 | sabha
# Processing Record 46 of Set 6 | nalut
# Processing Record 47 of Set 6 | sangar
# Processing Record 48 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 6 | teguise
# Processing Record 50 of Set 6 | murovani kurylivtsi
# Processing Record 1 of Set 7 | kothapet
# Processing Record 2 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 7 | anadyr
# Processing Record 4 of Set 7 | fairbanks
# Processing Record 5 of Set 7 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 6 of Set 7 | kpandae
# Processing Record 7 of Set 7 | namibe
# Processing Record 8 of Set 7 | gold coast
# Processing Record 9 of Set 7 | ust-nera
# Processing Record 10 of Set 7 | bukachacha
# Processing Record 11 of Set 7 | batemans bay
# Processing Record 12 of Set 7 | laplace
# Processing Record 13 of Set 7 | bowen
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | ambilobe
# Processing Record 16 of Set 7 | buwenge
# Processing Record 17 of Set 7 | noyabrsk
# Processing Record 18 of Set 7 | port elizabeth
# Processing Record 19 of Set 7 | clyde river
# Processing Record 20 of Set 7 | katherine
# Processing Record 21 of Set 7 | xuddur
# Processing Record 22 of Set 7 | majene
# Processing Record 23 of Set 7 | itarema
# Processing Record 24 of Set 7 | nakusp
# Processing Record 25 of Set 7 | oranjemund
# Processing Record 26 of Set 7 | big rapids
# Processing Record 27 of Set 7 | santo domingo
# Processing Record 28 of Set 7 | turukhansk
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | along
# Processing Record 31 of Set 7 | sao gabriel da cachoeira
# Processing Record 32 of Set 7 | bani walid
# Processing Record 33 of Set 7 | tchibanga
# Processing Record 34 of Set 7 | rawson
# Processing Record 35 of Set 7 | bintulu
# Processing Record 36 of Set 7 | ajdabiya
# Processing Record 37 of Set 7 | el cobre
# Processing Record 38 of Set 7 | mountrath
# Processing Record 39 of Set 7 | toamasina
# Processing Record 40 of Set 7 | ballina
# Processing Record 41 of Set 7 | cayenne
# Processing Record 42 of Set 7 | korampallam
# Processing Record 43 of Set 7 | buta
# Processing Record 44 of Set 7 | penaflor
# Processing Record 45 of Set 7 | valdosta
# Processing Record 46 of Set 7 | gwadar
# Processing Record 47 of Set 7 | jacareacanga
# Processing Record 48 of Set 7 | leopoldshohe
# Processing Record 49 of Set 7 | te anau
# Processing Record 50 of Set 7 | sorong
# Processing Record 1 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 8 | kysyl-syr
# Processing Record 3 of Set 8 | necochea
# Processing Record 4 of Set 8 | amberieu-en-bugey
# Processing Record 5 of Set 8 | coahuayana
# Processing Record 6 of Set 8 | tibagi
# Processing Record 7 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 8 | camrose
# Processing Record 9 of Set 8 | tarhunah
# City not found. Skipping...
# Processing Record 10 of Set 8 | arlit
# Processing Record 11 of Set 8 | yoichi
# Processing Record 12 of Set 8 | gulu
# Processing Record 13 of Set 8 | chokurdakh
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | svetlaya
# Processing Record 16 of Set 8 | hit
# Processing Record 17 of Set 8 | udachnyy
# Processing Record 18 of Set 8 | pochutla
# Processing Record 19 of Set 8 | warka
# Processing Record 20 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 8 | calvia
# Processing Record 22 of Set 8 | damara
# Processing Record 23 of Set 8 | belyy yar
# Processing Record 24 of Set 8 | tazovskiy
# Processing Record 25 of Set 8 | kaeo
# Processing Record 26 of Set 8 | massaguet
# Processing Record 27 of Set 8 | niquelandia
# Processing Record 28 of Set 8 | hamilton
# Processing Record 29 of Set 8 | tuscaloosa
# Processing Record 30 of Set 8 | guanica
# Processing Record 31 of Set 8 | phuket
# Processing Record 32 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 33 of Set 8 | katobu
# Processing Record 34 of Set 8 | santa helena
# Processing Record 35 of Set 8 | nhamunda
# Processing Record 36 of Set 8 | monrovia
# Processing Record 37 of Set 8 | sao joao da barra
# Processing Record 38 of Set 8 | ziro
# Processing Record 39 of Set 8 | ossora
# Processing Record 40 of Set 8 | barra do corda
# Processing Record 41 of Set 8 | tonota
# Processing Record 42 of Set 8 | sitrah
# Processing Record 43 of Set 8 | raudeberg
# Processing Record 44 of Set 8 | nabire
# Processing Record 45 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 8 | bairiki
# Processing Record 47 of Set 8 | hope
# Processing Record 48 of Set 8 | champerico
# Processing Record 49 of Set 8 | namatanai
# Processing Record 50 of Set 8 | naze
# Processing Record 1 of Set 9 | krapkowice
# Processing Record 2 of Set 9 | mkushi
# Processing Record 3 of Set 9 | benjamin constant
# Processing Record 4 of Set 9 | haines junction
# Processing Record 5 of Set 9 | kundiawa
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | dakar
# Processing Record 8 of Set 9 | puerto escondido
# Processing Record 9 of Set 9 | san quintin
# Processing Record 10 of Set 9 | cockburn town
# Processing Record 11 of Set 9 | cancun
# Processing Record 12 of Set 9 | dauriya
# Processing Record 13 of Set 9 | chirkey
# Processing Record 14 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 9 | tadine
# Processing Record 16 of Set 9 | itoman
# Processing Record 17 of Set 9 | ginir
# Processing Record 18 of Set 9 | panama city
# Processing Record 19 of Set 9 | ontario
# Processing Record 20 of Set 9 | wichita falls
# Processing Record 21 of Set 9 | sobolevo
# Processing Record 22 of Set 9 | norman wells
# Processing Record 23 of Set 9 | port lincoln
# Processing Record 24 of Set 9 | puerto ayacucho
# Processing Record 25 of Set 9 | sikeston
# Processing Record 26 of Set 9 | maple creek
# Processing Record 27 of Set 9 | rio grande
# Processing Record 28 of Set 9 | bafq
# Processing Record 29 of Set 9 | lagoa
# Processing Record 30 of Set 9 | iqaluit
# Processing Record 31 of Set 9 | pho chai
# Processing Record 32 of Set 9 | abu ghosh
# Processing Record 33 of Set 9 | fort pierce
# Processing Record 34 of Set 9 | bisho
# Processing Record 35 of Set 9 | svetlogorsk
# Processing Record 36 of Set 9 | kaohsiung
# Processing Record 37 of Set 9 | zakamensk
# Processing Record 38 of Set 9 | smidovich
# Processing Record 39 of Set 9 | bodden town
# Processing Record 40 of Set 9 | key west
# Processing Record 41 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 9 | bo
# City not found. Skipping...
# Processing Record 43 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 44 of Set 9 | begoro
# Processing Record 45 of Set 9 | pangnirtung
# Processing Record 46 of Set 9 | huarmey
# Processing Record 47 of Set 9 | surt
# Processing Record 48 of Set 9 | jambi
# Processing Record 49 of Set 9 | boyolangu
# Processing Record 50 of Set 9 | puerto baquerizo moreno
# Processing Record 1 of Set 10 | richards bay
# Processing Record 2 of Set 10 | ancud
# Processing Record 3 of Set 10 | sur
# Processing Record 4 of Set 10 | mogok
# Processing Record 5 of Set 10 | sunrise manor
# Processing Record 6 of Set 10 | kuntaur
# Processing Record 7 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 8 of Set 10 | hirara
# Processing Record 9 of Set 10 | talcahuano
# Processing Record 10 of Set 10 | brightwater
# Processing Record 11 of Set 10 | lorengau
# Processing Record 12 of Set 10 | puerto carreno
# Processing Record 13 of Set 10 | saquarema
# Processing Record 14 of Set 10 | port hedland
# Processing Record 15 of Set 10 | erzin
# Processing Record 16 of Set 10 | lisala
# Processing Record 17 of Set 10 | vila velha
# Processing Record 18 of Set 10 | slidell
# Processing Record 19 of Set 10 | abha
# Processing Record 20 of Set 10 | santo antonio do ica
# Processing Record 21 of Set 10 | miramar
# Processing Record 22 of Set 10 | viljoenskroon
# Processing Record 23 of Set 10 | leogane
# Processing Record 24 of Set 10 | isangel
# Processing Record 25 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 26 of Set 10 | algiers
# Processing Record 27 of Set 10 | korla
# Processing Record 28 of Set 10 | sabang
# Processing Record 29 of Set 10 | nanakuli
# Processing Record 30 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 31 of Set 10 | ughelli
# Processing Record 32 of Set 10 | ahipara
# Processing Record 33 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | keti bandar
# Processing Record 36 of Set 10 | alofi
# Processing Record 37 of Set 10 | mahebourg
# Processing Record 38 of Set 10 | mercedes
# Processing Record 39 of Set 10 | dzaoudzi
# Processing Record 40 of Set 10 | grindavik
# Processing Record 41 of Set 10 | ukholovo
# Processing Record 42 of Set 10 | soyo
# Processing Record 43 of Set 10 | udomlya
# Processing Record 44 of Set 10 | stromness
# Processing Record 45 of Set 10 | marfino
# Processing Record 46 of Set 10 | soure
# Processing Record 47 of Set 10 | mana
# Processing Record 48 of Set 10 | coihaique
# Processing Record 49 of Set 10 | seminole
# Processing Record 50 of Set 10 | milkovo
# Processing Record 1 of Set 11 | vestmannaeyjar
# Processing Record 2 of Set 11 | terra boa
# Processing Record 3 of Set 11 | oranjestad
# Processing Record 4 of Set 11 | chimbote
# Processing Record 5 of Set 11 | shetpe
# Processing Record 6 of Set 11 | lisakovsk
# Processing Record 7 of Set 11 | camopi
# Processing Record 8 of Set 11 | bondo
# Processing Record 9 of Set 11 | xai-xai
# Processing Record 10 of Set 11 | pierre
# Processing Record 11 of Set 11 | pozhva
# Processing Record 12 of Set 11 | jalu
# Processing Record 13 of Set 11 | avera
# Processing Record 14 of Set 11 | rehoboth
# Processing Record 15 of Set 11 | savannah bight
# Processing Record 16 of Set 11 | emirdag
# Processing Record 17 of Set 11 | kimbe
# Processing Record 18 of Set 11 | lucapa
# Processing Record 19 of Set 11 | shelburne
# Processing Record 20 of Set 11 | rusape
# Processing Record 21 of Set 11 | porto velho
# Processing Record 22 of Set 11 | livingston
# Processing Record 23 of Set 11 | margate
# Processing Record 24 of Set 11 | meulaboh
# Processing Record 25 of Set 11 | hasaki
# Processing Record 26 of Set 11 | nouadhibou
# Processing Record 27 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 28 of Set 11 | bilma
# Processing Record 29 of Set 11 | ponta pora
# Processing Record 30 of Set 11 | capao da canoa
# Processing Record 31 of Set 11 | pontianak
# Processing Record 32 of Set 11 | humaita
# Processing Record 33 of Set 11 | jinhua
# Processing Record 34 of Set 11 | cao bang
# Processing Record 35 of Set 11 | camacha
# Processing Record 36 of Set 11 | taua
# Processing Record 37 of Set 11 | kayerkan
# Processing Record 38 of Set 11 | laguna
# Processing Record 39 of Set 11 | saint george
# Processing Record 40 of Set 11 | yucca valley
# Processing Record 41 of Set 11 | isilkul
# Processing Record 42 of Set 11 | hobyo
# Processing Record 43 of Set 11 | liverpool
# Processing Record 44 of Set 11 | saint-georges
# Processing Record 45 of Set 11 | lakes entrance
# Processing Record 46 of Set 11 | zapolyarnyy
# Processing Record 47 of Set 11 | mangrol
# Processing Record 48 of Set 11 | dargaville
# Processing Record 49 of Set 11 | iberia
# Processing Record 50 of Set 11 | ho chi minh city
# Processing Record 1 of Set 12 | mahina
# Processing Record 2 of Set 12 | paita
# Processing Record 3 of Set 12 | talnakh
# Processing Record 4 of Set 12 | sao filipe
# Processing Record 5 of Set 12 | mwinilunga
# Processing Record 6 of Set 12 | manoel urbano
# Processing Record 7 of Set 12 | pokhvistnevo
# Processing Record 8 of Set 12 | lima
# Processing Record 9 of Set 12 | chipinge
# Processing Record 10 of Set 12 | leshukonskoye
# Processing Record 11 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 12 | kalachinsk
# Processing Record 13 of Set 12 | antsohihy
# Processing Record 14 of Set 12 | seoul
# Processing Record 15 of Set 12 | amazar
# Processing Record 16 of Set 12 | vestmanna
# Processing Record 17 of Set 12 | igarka
# Processing Record 18 of Set 12 | nyurba
# Processing Record 19 of Set 12 | doctor arroyo
# Processing Record 20 of Set 12 | cabra
# Processing Record 21 of Set 12 | shimoda
# Processing Record 22 of Set 12 | southbridge
# Processing Record 23 of Set 12 | pafos
# Processing Record 24 of Set 12 | lasa
# Processing Record 25 of Set 12 | mahibadhoo
# Processing Record 26 of Set 12 | paranagua
# Processing Record 27 of Set 12 | port keats
# Processing Record 28 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 12 | opelika
# Processing Record 30 of Set 12 | marshall
# Processing Record 31 of Set 12 | dwarka
# Processing Record 32 of Set 12 | khandyga
# Processing Record 33 of Set 12 | huanren
# Processing Record 34 of Set 12 | lhokseumawe
# Processing Record 35 of Set 12 | zaragoza
# Processing Record 36 of Set 12 | canyon
# Processing Record 37 of Set 12 | inhambane
# Processing Record 38 of Set 12 | pizarro
# Processing Record 39 of Set 12 | guaraniacu
# Processing Record 40 of Set 12 | mitu
# Processing Record 41 of Set 12 | mogadishu
# Processing Record 42 of Set 12 | abu zabad
# Processing Record 43 of Set 12 | cap malheureux
# Processing Record 44 of Set 12 | mount gambier
# Processing Record 45 of Set 12 | araguaina
# Processing Record 46 of Set 12 | cidreira
# Processing Record 47 of Set 12 | kilcock
# Processing Record 48 of Set 12 | adamas
# Processing Record 49 of Set 12 | tame
# Processing Record 50 of Set 12 | komsomolskiy
# Processing Record 1 of Set 13 | kamal
# Processing Record 2 of Set 13 | abu samrah
# Processing Record 3 of Set 13 | ambon
# Processing Record 4 of Set 13 | bandarbeyla
# Processing Record 5 of Set 13 | torbay
# Processing Record 6 of Set 13 | zhoucheng
# Processing Record 7 of Set 13 | mahbubabad
# Processing Record 8 of Set 13 | la palma
# Processing Record 9 of Set 13 | pau dos ferros
# Processing Record 10 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 13 | suez
# Processing Record 12 of Set 13 | semirom
# Processing Record 13 of Set 13 | high level
# Processing Record 14 of Set 13 | jaciara
# Processing Record 15 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 13 | san francisco
# Processing Record 17 of Set 13 | vardo
# Processing Record 18 of Set 13 | trinidad
# Processing Record 19 of Set 13 | longyan
# Processing Record 20 of Set 13 | yamoussoukro
# Processing Record 21 of Set 13 | chapleau
# Processing Record 22 of Set 13 | krasnoselkup
# Processing Record 23 of Set 13 | joyabaj
# Processing Record 24 of Set 13 | fort nelson
# Processing Record 25 of Set 13 | guerrero negro
# Processing Record 26 of Set 13 | waingapu
# Processing Record 27 of Set 13 | villazon
# Processing Record 28 of Set 13 | san gabriel
# Processing Record 29 of Set 13 | tutoia
# Processing Record 30 of Set 13 | wenceslau braz
# Processing Record 31 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 13 | zelenoborskiy
# Processing Record 33 of Set 13 | araouane
# Processing Record 34 of Set 13 | egvekinot
# Processing Record 35 of Set 13 | wesselsbron
# Processing Record 36 of Set 13 | pop
# Processing Record 37 of Set 13 | hualmay
# Processing Record 38 of Set 13 | owando
# Processing Record 39 of Set 13 | port-gentil
# Processing Record 40 of Set 13 | anloga
# Processing Record 41 of Set 13 | caernarfon
# Processing Record 42 of Set 13 | porbandar
# Processing Record 43 of Set 13 | burica
# City not found. Skipping...
# Processing Record 44 of Set 13 | mehamn
# Processing Record 45 of Set 13 | dergachi
# Processing Record 46 of Set 13 | havelock
# Processing Record 47 of Set 13 | tocache
# Processing Record 48 of Set 13 | djambala
# Processing Record 49 of Set 13 | shubarshi
# Processing Record 50 of Set 13 | abu road
# Processing Record 1 of Set 14 | sterling
# Processing Record 2 of Set 14 | miraflores
# Processing Record 3 of Set 14 | alta floresta
# Processing Record 4 of Set 14 | biak
# Processing Record 5 of Set 14 | rio verde de mato grosso
# Processing Record 6 of Set 14 | port augusta
# Processing Record 7 of Set 14 | tabuk
# Processing Record 8 of Set 14 | segou
# Processing Record 9 of Set 14 | ustyuzhna
# Processing Record 10 of Set 14 | amahai
# Processing Record 11 of Set 14 | telde
# Processing Record 12 of Set 14 | corby
# Processing Record 13 of Set 14 | grand gaube
# Processing Record 14 of Set 14 | greve strand
# Processing Record 15 of Set 14 | ponnani
# Processing Record 16 of Set 14 | lithakia
# Processing Record 17 of Set 14 | half moon bay
# Processing Record 18 of Set 14 | ipixuna
# Processing Record 19 of Set 14 | bambanglipuro
# Processing Record 20 of Set 14 | xiaoweizhai
# Processing Record 21 of Set 14 | boca do acre
# Processing Record 22 of Set 14 | zaranj
# Processing Record 23 of Set 14 | sosnovskiy
# City not found. Skipping...
# Processing Record 24 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 14 | aklavik
# Processing Record 26 of Set 14 | hay river
# Processing Record 27 of Set 14 | touros
# Processing Record 28 of Set 14 | champasak
# Processing Record 29 of Set 14 | bandarban
# Processing Record 30 of Set 14 | rabo de peixe
# Processing Record 31 of Set 14 | san cristobal
# Processing Record 32 of Set 14 | satkhira
# Processing Record 33 of Set 14 | hastings
# Processing Record 34 of Set 14 | tuy hoa
# Processing Record 35 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 14 | san jeronimo
# Processing Record 37 of Set 14 | berezovyy
# Processing Record 38 of Set 14 | natal
# Processing Record 39 of Set 14 | kimberley
# Processing Record 40 of Set 14 | lavrentiya
# Processing Record 41 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 14 | zhovkva
# Processing Record 43 of Set 14 | kaura namoda
# Processing Record 44 of Set 14 | nha trang
# Processing Record 45 of Set 14 | kaseda
# Processing Record 46 of Set 14 | opuwo
# Processing Record 47 of Set 14 | husavik
# Processing Record 48 of Set 14 | lagos
# Processing Record 49 of Set 14 | makokou
# Processing Record 50 of Set 14 | gao
# Processing Record 1 of Set 15 | konevo
# Processing Record 2 of Set 15 | kannabe
# Processing Record 3 of Set 15 | inirida
# Processing Record 4 of Set 15 | mbinga
# Processing Record 5 of Set 15 | boende
# Processing Record 6 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 15 | henties bay
# Processing Record 8 of Set 15 | duz
# City not found. Skipping...
# Processing Record 9 of Set 15 | mairipora
# Processing Record 10 of Set 15 | grand-santi
# Processing Record 11 of Set 15 | stefanesti
# Processing Record 12 of Set 15 | novopokrovka
# Processing Record 13 of Set 15 | calama
# Processing Record 14 of Set 15 | hede
# Processing Record 15 of Set 15 | green valley
# Processing Record 16 of Set 15 | kampene
# Processing Record 17 of Set 15 | gamboma
# Processing Record 18 of Set 15 | loviisa
# Processing Record 19 of Set 15 | amuntai
# Processing Record 20 of Set 15 | tual
# Processing Record 21 of Set 15 | potsdam
# Processing Record 22 of Set 15 | romitan
# Processing Record 23 of Set 15 | puerto leguizamo
# Processing Record 24 of Set 15 | tevaitoa
# Processing Record 25 of Set 15 | arman
# Processing Record 26 of Set 15 | atambua
# Processing Record 27 of Set 15 | copiapo
# Processing Record 28 of Set 15 | manaus
# Processing Record 29 of Set 15 | freeport
# Processing Record 30 of Set 15 | semey
# Processing Record 31 of Set 15 | timmins
# Processing Record 32 of Set 15 | barguzin
# Processing Record 33 of Set 15 | micheweni
# Processing Record 34 of Set 15 | madingou
# Processing Record 35 of Set 15 | campbell river
# Processing Record 36 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 15 | ternate
# Processing Record 38 of Set 15 | qandala
# Processing Record 39 of Set 15 | akdepe
# Processing Record 40 of Set 15 | moose jaw
# Processing Record 41 of Set 15 | santa barbara
# Processing Record 42 of Set 15 | teguldet
# Processing Record 43 of Set 15 | yecla
# Processing Record 44 of Set 15 | verkhoshizhemye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tarakan   3.3000  117.6333     79.56        79          93
# 1          Bourail -21.5667  165.4833     78.73        78         100
# 2       Hambantota   6.1241   81.1185     75.76        81           4
# 3             Poum -20.2333  164.0167     80.33        76         100
# 4         Tamworth  52.6340   -1.6959     44.35        88          80
# 5         Coquimbo -29.9533  -71.3436     69.53        68          20
# 6          Tautira -17.7333 -149.1500     84.00        78          35
# 7    Lengshuijiang  27.6881  111.4294     36.86       100         100
# 8     Ponta Do Sol  32.6667  -17.1000     66.00        57          37
# 9  Arraial Do Cabo -22.9661  -42.0278     80.46        78          75
#
#    Wind Speed Country                 Date Current Description
# 0        9.53      ID  2022-01-31 21:06:45     overcast clouds
# 1        3.00      NC  2022-01-31 21:06:45     overcast clouds
# 2       15.97      LK  2022-01-31 21:06:45           clear sky
# 3       14.63      NC  2022-01-31 21:06:46     overcast clouds
# 4        5.01      GB  2022-01-31 21:06:46       broken clouds
# 5       13.80      CL  2022-01-31 20:56:51          few clouds
# 6       19.22      PF  2022-01-31 21:06:47          light rain
# 7        1.68      CN  2022-01-31 21:06:48          light rain
# 8       13.06      PT  2022-01-31 21:01:00    scattered clouds
# 9        3.44      BR  2022-01-31 21:06:49       broken clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0          Tarakan      ID  2022-01-31 21:06:45   3.3000  117.6333     79.56
# 1          Bourail      NC  2022-01-31 21:06:45 -21.5667  165.4833     78.73
# 2       Hambantota      LK  2022-01-31 21:06:45   6.1241   81.1185     75.76
# 3             Poum      NC  2022-01-31 21:06:46 -20.2333  164.0167     80.33
# 4         Tamworth      GB  2022-01-31 21:06:46  52.6340   -1.6959     44.35
# 5         Coquimbo      CL  2022-01-31 20:56:51 -29.9533  -71.3436     69.53
# 6          Tautira      PF  2022-01-31 21:06:47 -17.7333 -149.1500     84.00
# 7    Lengshuijiang      CN  2022-01-31 21:06:48  27.6881  111.4294     36.86
# 8     Ponta Do Sol      PT  2022-01-31 21:01:00  32.6667  -17.1000     66.00
# 9  Arraial Do Cabo      BR  2022-01-31 21:06:49 -22.9661  -42.0278     80.46
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        79          93        9.53     overcast clouds
# 1        78         100        3.00     overcast clouds
# 2        81           4       15.97           clear sky
# 3        76         100       14.63     overcast clouds
# 4        88          80        5.01       broken clouds
# 5        68          20       13.80          few clouds
# 6        78          35       19.22          light rain
# 7       100         100        1.68          light rain
# 8        57          37       13.06    scattered clouds
# 9        78          75        3.44       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
